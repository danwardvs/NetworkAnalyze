# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_json('data/data2.json')


df = pd.DataFrame([device for device in df.devices])

df
# Out:
#           address           firstseen   hardware_address   make        model  \
# 0      10.84.64.1  2020-01-22 4:51 PM  00:08:E3:FF:FC:28    NaN          NaN
# 1      10.84.65.1  2020-01-22 4:51 PM  00:B3:62:C0:21:B9  Apple       iPhone
# 2      10.84.65.4  2020-01-22 4:51 PM  10:94:BB:D7:A0:04  Apple      MacBook
# 3      10.84.65.5  2020-01-22 4:51 PM  F4:5C:89:A7:E8:17  Apple  MacBook PRO
# 4      10.84.65.6  2020-01-22 4:51 PM  30:57:14:7B:8D:7A  Apple       iPhone
# ..            ...                 ...                ...    ...          ...
# 902   10.84.94.91  2020-01-22 4:51 PM  14:C2:13:B8:A5:FC  Apple          NaN
# 903   10.84.94.94  2020-01-22 4:51 PM  DC:A9:04:72:0F:A9  Apple  MacBook PRO
# 904  10.84.94.101  2020-01-22 4:51 PM  F4:AF:E7:D0:6F:F1  Apple       iPhone
# 905  10.84.94.108  2020-01-22 4:51 PM  38:F9:D3:87:BA:F7  Apple      MacBook
# 906  10.84.94.114  2020-01-22 4:51 PM  CC:D2:81:50:39:F2  Apple       iPhone
#
#                 name state    type
# 0                NaN    UP  Router
# 1                NaN    UP  Mobile
# 2                NaN    UP  Laptop
# 3    MACBOOKPRO-E817    UP  Laptop
# 4                NaN    UP  Mobile
# ..               ...   ...     ...
# 902              NaN    UP  Mobile
# 903  MACBOOKPRO-0FA9    UP  Laptop
# 904              NaN    UP  Mobile
# 905  MACBOOKAIR-BAF7    UP  Laptop
# 906              NaN    UP  Mobile
#
# [907 rows x 8 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_json('data/data2.json')



df = pd.DataFrame([device for device in df.devices])

names = df['name'].value_counts()

names = names.keys()

for name in names:
    if 'MACBOOK' not in name:
        print(name)

# %%
df = pd.read_json('data/data2.json')



df = pd.DataFrame([device for device in df.devices])

df['make'].fillna('Unknown',inplace=True)

makes = df['make'].value_counts()
main = makes[makes > 7]
other = makes[makes<=7]
main = main.append(pd.Series([other.sum()],['Other']))

explode = []

for i in range(len(main)-1):
    explode.append(0)
explode.append(0.2)

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '({v:d})'.format(v=val)
    return my_autopct

main.plot.pie(explode=explode, autopct = make_autopct(main))

plt.title("Manufacturers of Devices",size=16)
plt.ylabel("")
plt.show()

other.plot.pie(autopct = make_autopct(other))
plt.title("Other Devices",size=16)
plt.ylabel("")


plt.show()

# %%
df = pd.read_json('data/data2.json')

filter = 'model'

df = pd.DataFrame([device for device in df.devices])

df[filter].fillna('Unknown',inplace=True)

makes = df[filter].value_counts()
main = makes[makes > 7]
other = makes[makes<=7]
main = main.append(pd.Series([other.sum()],['Other']))

explode = []

for i in range(len(main)-1):
    explode.append(0)
explode.append(0.2)

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '({v:d})'.format(v=val)
    return my_autopct

main.plot.pie(explode=explode, autopct = make_autopct(main))

plt.title("Models of Devices",size=16)
plt.ylabel("")
plt.show()

plt.subplots(figsize=(10,5))
other.plot.bar()

plt.title("Other Devices",size=16)
plt.ylabel("")


plt.show()

# %%
df = pd.read_json('data/data2.json')



df = pd.DataFrame([device for device in df.devices])

df['type'].fillna('Unknown',inplace=True)
df['type'].replace('Generic','Unknown',inplace=True)

makes = df['type'].value_counts()
main = makes[makes > 22]
other = makes[makes<=22]
main = main.append(pd.Series([other.sum()],['Other']))

explode = []

for i in range(len(main)-1):
    explode.append(0)
explode.append(0.2)

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '({v:d})'.format(v=val)
    return my_autopct

main.plot.pie(explode=explode, autopct = make_autopct(main))

plt.title("Types of Devices",size=16)
plt.ylabel("")
plt.show()

other.plot.pie(autopct = make_autopct(other))
plt.title("Other Devices",size=16)
plt.ylabel("")


plt.show()
